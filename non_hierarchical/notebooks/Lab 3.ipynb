# %% [markdown]
# # Imports Required for Lab

# %%
# Standard Libararies
import os
import random 
import textwrap
import numpy as np
import pandas as pd

# Progress Bars
from tqdm import tqdm

# Neueral Networks
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchvision.models as models

# Plotting and Image Processing
# %matplotlib inline
import matplotlib.pyplot as plt
from PIL import Image
from skimage.transform import resize

# Memory Optimization
from joblib import dump
from joblib import load
import gc

# %%
print("Using torch", torch.__version__)
# Out:
# Using torch 2.4.0.post101

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


gpu_avail = torch.cuda.is_available()
print(f"Is the GPU available? {gpu_avail}")

mps_avail = torch.backends.mps.is_available()
print(f"Is the Mac MPS (GPU for Mac) available? {mps_avail}")

if(gpu_avail):
    device = "cuda"
elif(mps_avail):
    device = "mps"
else:
    device = "cpu"
# Out:
# Is the GPU available? False
# Is the Mac MPS (GPU for Mac) available? True

# %% [markdown]
# # Question 5

# %%
training_classifications = 'training_classifications.csv'
training_classifications_df = pd.read_csv('training_classifications.csv')
training_classifications_df
# Out:
#        GalaxyID  Class1.1  Class1.2  Class1.3  Class2.1  Class2.2  Class3.1  \
# 0        100008  0.383147  0.616853  0.000000  0.000000  0.616853  0.038452
# 1        100023  0.327001  0.663777  0.009222  0.031178  0.632599  0.467370
# 2        100053  0.765717  0.177352  0.056931  0.000000  0.177352  0.000000
# 3        100078  0.693377  0.238564  0.068059  0.000000  0.238564  0.109493
# 4        100090  0.933839  0.000000  0.066161  0.000000  0.000000  0.000000
# ...         ...       ...       ...       ...       ...       ...       ...
# 61573    999948  0.510379  0.489621  0.000000  0.059207  0.430414  0.000000
# 61574    999950  0.901216  0.098784  0.000000  0.000000  0.098784  0.000000
# 61575    999958  0.202841  0.777376  0.019783  0.116962  0.660414  0.067245
# 61576    999964  0.091000  0.909000  0.000000  0.045450  0.863550  0.022452
# 61577    999967  0.767000  0.140000  0.093000  0.000000  0.140000  0.000000
#
#        Class3.2  Class4.1  Class4.2  ...  Class9.3  Class10.1  Class10.2  \
# 0      0.578401  0.418398  0.198455  ...  0.000000   0.279952   0.138445
# 1      0.165229  0.591328  0.041271  ...  0.018764   0.000000   0.131378
# 2      0.177352  0.000000  0.177352  ...  0.000000   0.000000   0.000000
# 3      0.129071  0.189098  0.049466  ...  0.000000   0.094549   0.000000
# 4      0.000000  0.000000  0.000000  ...  0.000000   0.000000   0.000000
# ...         ...       ...       ...  ...       ...        ...        ...
# 61573  0.430414  0.226257  0.204157  ...  0.000000   0.226257   0.000000
# 61574  0.098784  0.000000  0.098784  ...  0.000000   0.000000   0.000000
# 61575  0.593168  0.140022  0.520391  ...  0.000000   0.000000   0.090673
# 61576  0.841098  0.795330  0.068220  ...  0.000000   0.068398   0.318132
# 61577  0.140000  0.023380  0.116620  ...  0.000000   0.023380   0.000000
#
#        Class10.3  Class11.1  Class11.2  Class11.3  Class11.4  Class11.5  \
# 0       0.000000   0.000000   0.092886   0.000000   0.000000        0.0
# 1       0.459950   0.000000   0.591328   0.000000   0.000000        0.0
# 2       0.000000   0.000000   0.000000   0.000000   0.000000        0.0
# 3       0.094549   0.189098   0.000000   0.000000   0.000000        0.0
# 4       0.000000   0.000000   0.000000   0.000000   0.000000        0.0
# ...          ...        ...        ...        ...        ...        ...
# 61573   0.000000   0.000000   0.000000   0.000000   0.000000        0.0
# 61574   0.000000   0.000000   0.000000   0.000000   0.000000        0.0
# 61575   0.049349   0.000000   0.067726   0.000000   0.000000        0.0
# 61576   0.408799   0.227464   0.408799   0.090668   0.023065        0.0
# 61577   0.000000   0.000000   0.000000   0.000000   0.000000        0.0
#
#        Class11.6
# 0       0.325512
# 1       0.000000
# 2       0.000000
# 3       0.000000
# 4       0.000000
# ...          ...
# 61573   0.226257
# 61574   0.000000
# 61575   0.072296
# 61576   0.045334
# 61577   0.023380
#
# [61578 rows x 38 columns]

# %% [markdown]
# **How many images are in the training set?**
#
# There are 61578 images in the training set

# %%
os.listdir('training_images')[0]
# Out:
# '873932.jpg'

# %%
# Function to add white border around plots for ease of visibility
def add_subplot_border(ax, width=1, color=None):

    fig = ax.get_figure()

    # Convert bottom-left and top-right to display coordinates
    x0, y0 = ax.transAxes.transform((0, 0))
    x1, y1 = ax.transAxes.transform((1, 1))

    # Convert back to Axes coordinates
    x0, y0 = ax.transAxes.inverted().transform((x0, y0))
    x1, y1 = ax.transAxes.inverted().transform((x1, y1))

    rect = plt.Rectangle(
        (x0, y0), x1-x0, y1-y0,
        color=color,
        transform=ax.transAxes,
        zorder=-1,
        lw=2*width+1,
        fill=None,
    )
    fig.patches.append(rect)

# %%
# Use dark background
plt.style.use('dark_background')

# %%
# Plot the 25 randomly selected images
random.seed(42)

root = "../../lab_notebooks/Lab 3/training_images"
cols, rows = 5, 5

# Make a new figure and define dark themed style
figure = plt.figure(figsize=(12,12))

# Create plotted filenames array for later
plotted_images = []

for i in range(1, cols * rows + 1):
    rand_idx = random.randint(0, 61577)
    ax = figure.add_subplot(rows, cols, i)
    filename = f"{training_classifications_df['GalaxyID'].iloc[rand_idx]}.jpg"
    img = plt.imread(os.path.join(root, filename))
    plotted_images.append(img)
    plt.imshow(img)
    plt.title(f"{filename}")
    plt.axis('off')
    add_subplot_border(ax, width=2, color='white')

plt.subplots_adjust(wspace=0.3, hspace=0.3)
plt.show()

# %%
print(type(img))
# Out:
# <class 'numpy.ndarray'>

# %%
print(img.shape[:2])
# Out:
# (424, 424)

# %% [markdown]
# **What is their dimension?**
#
# The Image is of dimension 424 x 424 pixels

# %% [markdown]
# # Question 6

# %%
classification_names = ['GalaxyID',
                        'Amount of Smoothness for a disk',
                        'Signs of features or a disk',
                        'Classified as Star or Artifact',
                        'Disk can be viewed edge-on',
                        'Disk cannot be viewed edge-on',
                        'Bar or feature through centre of galaxy detected',
                        'Bar or feautre through centre of galaxy not detected',
                        'Signs of a spiral arm pattern',
                        'No signs of a spiral arm pattern',
                        'No bulge',
                        'Just noticeable bulge',
                        'Obvious bulge',
                        'Dominant bulge',
                        'Odd features in image',
                        'No odd features in image',
                        'Completely round',
                        'In-between round and cigar',
                        'Cigar-shaped',
                        'Presence of Ring',
                        'Presence of lens or arc',
                        'Disturbed galaxy',
                        'Irregular galaxy',
                        'Presence of other odd features',
                        'Merger galaxies',
                        'Presence of dust lane',
                        'Rounded bulge at centre',
                        'Boxy bulge at centre',
                        'No bulge at centre',
                        'Tight spiral arms',
                        'Medium spiral arms',
                        'Loose spiral arms',
                        '1 spiral arm',
                        '2 spiral arms',
                        '3 spiral arms',
                        '4 spiral arms',
                        'More than 4 spiral arms',
                        'Can\'t tell if any spiral arms exist']

# define variable to store number of lables
num_labels = len(training_classifications_df.dtypes.index.tolist())

print(num_labels)
print(len(classification_names))
# Out:
# 38
# 38

# %%
def wrap_title(text, width):
    return "\n".join(textwrap.wrap(text, width=width))

# %%
# Make a new figure and define dark themed style
figure = plt.figure(figsize=(12,12))
rows, cols = 10, 4

for i in range(1, len(classification_names)):
    ax = figure.add_subplot(rows, cols, i)
    vals = training_classifications_df.iloc[:, i]
    plt.hist(vals)
    plt.title(wrap_title(classification_names[i], width=25), fontsize=11)
    add_subplot_border(ax, width=1, color='white')

# plt.tight_layout()
plt.subplots_adjust(left=0.1, right=0.9, top=1.7, bottom=0.0, wspace=0.7, hspace=0.5)
plt.show()

# %% [markdown]
# **Comment on the distributions. Are any of them multi-modal, or particularly skewed? What does that tell us about that label?**

# %% [markdown]
# # Question 7

# %%
max_rows = training_classifications_df.idxmax()
maxxed_df = training_classifications_df.loc[max_rows]
maxxed_df
# Out:
#        GalaxyID  Class1.1  Class1.2  Class1.3  Class2.1  Class2.2  Class3.1  \
# 61577    999967  0.767000  0.140000  0.093000  0.000000  0.140000  0.000000
# 369      105447  1.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 56       100859  0.000000  1.000000  0.000000  0.040909  0.959091  0.133534
# 17392    356310  0.064853  0.000000  0.935147  0.000000  0.000000  0.000000
# 16564    344604  0.000000  1.000000  0.000000  1.000000  0.000000  0.000000
# 342      105009  0.000000  1.000000  0.000000  0.000000  1.000000  0.833000
# 7163     205541  0.000000  1.000000  0.000000  0.000000  1.000000  1.000000
# 5763     185561  0.000000  1.000000  0.000000  0.000000  1.000000  0.000000
# 342      105009  0.000000  1.000000  0.000000  0.000000  1.000000  0.833000
# 46730    780966  0.000000  0.999000  0.001000  0.032463  0.966537  0.966537
# 24281    454627  0.103211  0.896789  0.000000  0.024671  0.872118  0.689444
# 41528    706376  0.000000  1.000000  0.000000  0.000000  1.000000  0.894272
# 5455     180894  0.108966  0.891034  0.000000  0.000000  0.891034  0.575833
# 53289    877297  0.062724  0.933422  0.003855  0.114459  0.818963  0.221614
# 2239     133499  0.019505  0.963733  0.016762  0.013871  0.949862  0.026227
# 2        100053  0.765717  0.177352  0.056931  0.000000  0.177352  0.000000
# 33146    585988  1.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 30399    545652  1.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 50415    834060  1.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 25883    478315  0.032876  0.967124  0.000000  0.042537  0.924587  0.153725
# 34759    608304  0.264018  0.706076  0.029906  0.000000  0.706076  0.000000
# 52770    869304  0.254178  0.729901  0.015921  0.036495  0.693406  0.067423
# 38518    662018  0.286212  0.697870  0.015918  0.000000  0.697870  0.032961
# 25461    471591  0.655736  0.237580  0.106684  0.052035  0.185545  0.000000
# 18605    373505  0.000000  0.984010  0.015990  0.000000  0.984010  0.456347
# 52748    868815  0.439525  0.543804  0.016671  0.492252  0.051552  0.000000
# 49947    827293  0.014018  0.985982  0.000000  0.985982  0.000000  0.000000
# 4185     162557  0.005052  0.994948  0.000000  0.994948  0.000000  0.000000
# 509      107454  0.093634  0.901991  0.004376  0.901991  0.000000  0.000000
# 14112    309198  0.000000  1.000000  0.000000  0.000000  1.000000  0.013328
# 1433     121394  0.000000  1.000000  0.000000  0.000000  1.000000  0.642087
# 21666    416488  0.003048  0.996952  0.000000  0.000000  0.996952  0.270057
# 51414    848818  0.027593  0.972407  0.000000  0.000000  0.972407  0.525576
# 342      105009  0.000000  1.000000  0.000000  0.000000  1.000000  0.833000
# 1399     121006  0.009972  0.975913  0.014115  0.000000  0.975913  0.033411
# 8992     233081  0.000000  1.000000  0.000000  0.000000  1.000000  0.043000
# 27011    495381  0.000000  1.000000  0.000000  0.020000  0.980000  0.081340
# 34046    598442  0.191757  0.808243  0.000000  0.000000  0.808243  0.196350
#
#        Class3.2  Class4.1  Class4.2  ...  Class9.3  Class10.1  Class10.2  \
# 61577  0.140000  0.023380  0.116620  ...  0.000000   0.023380   0.000000
# 369    0.000000  0.000000  0.000000  ...  0.000000   0.000000   0.000000
# 56     0.825557  0.816533  0.142558  ...  0.000000   0.015459   0.000000
# 17392  0.000000  0.000000  0.000000  ...  0.000000   0.000000   0.000000
# 16564  0.000000  0.000000  0.000000  ...  0.000000   0.000000   0.000000
# 342    0.167000  1.000000  0.000000  ...  0.000000   0.214000   0.429000
# 7163   0.000000  0.970354  0.029646  ...  0.000000   0.000000   0.839915
# 5763   1.000000  1.000000  0.000000  ...  0.000000   0.812813   0.125125
# 342    0.167000  1.000000  0.000000  ...  0.000000   0.214000   0.429000
# 46730  0.000000  0.008600  0.957937  ...  0.000000   0.004020   0.004580
# 24281  0.182675  0.280172  0.591947  ...  0.024671   0.055511   0.137888
# 41528  0.105728  0.981668  0.018332  ...  0.000000   0.000000   0.115539
# 5455   0.315201  0.203866  0.687168  ...  0.000000   0.063776   0.140090
# 53289  0.597349  0.798511  0.020452  ...  0.000000   0.000000   0.000000
# 2239   0.923635  0.496760  0.453102  ...  0.000000   0.022628   0.021648
# 2      0.177352  0.000000  0.177352  ...  0.000000   0.000000   0.000000
# 33146  0.000000  0.000000  0.000000  ...  0.000000   0.000000   0.000000
# 30399  0.000000  0.000000  0.000000  ...  0.000000   0.000000   0.000000
# 50415  0.000000  0.000000  0.000000  ...  0.000000   0.000000   0.000000
# 25883  0.770862  0.062510  0.862077  ...  0.000000   0.000000   0.062510
# 34759  0.706076  0.193110  0.512966  ...  0.000000   0.000000   0.110854
# 52770  0.625983  0.670060  0.023346  ...  0.000000   0.236531   0.196998
# 38518  0.664909  0.048469  0.649401  ...  0.000000   0.000000   0.000000
# 25461  0.185545  0.000000  0.185545  ...  0.000000   0.000000   0.000000
# 18605  0.527663  0.984010  0.000000  ...  0.000000   0.000000   0.311107
# 52748  0.051552  0.003946  0.047606  ...  0.123063   0.003946   0.000000
# 49947  0.000000  0.000000  0.000000  ...  0.000000   0.000000   0.000000
# 4185   0.000000  0.000000  0.000000  ...  0.038087   0.000000   0.000000
# 509    0.000000  0.000000  0.000000  ...  0.901991   0.000000   0.000000
# 14112  0.986672  1.000000  0.000000  ...  0.000000   0.949733   0.050267
# 1433   0.357913  1.000000  0.000000  ...  0.000000   0.044547   0.877393
# 21666  0.726895  0.996952  0.000000  ...  0.000000   0.000000   0.000000
# 51414  0.446831  0.947982  0.024425  ...  0.000000   0.061619   0.122290
# 342    0.167000  1.000000  0.000000  ...  0.000000   0.214000   0.429000
# 1399   0.942502  0.975913  0.000000  ...  0.000000   0.435312   0.540601
# 8992   0.957000  1.000000  0.000000  ...  0.000000   0.391000   0.435000
# 27011  0.898660  0.980000  0.000000  ...  0.020000   0.756783   0.202657
# 34046  0.611893  0.753082  0.055161  ...  0.000000   0.645391   0.107691
#
#        Class10.3  Class11.1  Class11.2  Class11.3  Class11.4  Class11.5  \
# 61577   0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 369     0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 56      0.801074   0.000000   0.785880   0.030653   0.000000   0.000000
# 17392   0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 16564   0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 342     0.357000   0.000000   1.000000   0.000000   0.000000   0.000000
# 7163    0.130439   0.000000   0.774161   0.059270   0.000000   0.136923
# 5763    0.062062   0.000000   0.875876   0.062062   0.000000   0.000000
# 342     0.357000   0.000000   1.000000   0.000000   0.000000   0.000000
# 46730   0.000000   0.000000   0.006360   0.000000   0.000000   0.000000
# 24281   0.086773   0.021979   0.135580   0.031992   0.057459   0.006680
# 41528   0.866129   0.000000   0.981668   0.000000   0.000000   0.000000
# 5455    0.000000   0.000000   0.098093   0.000000   0.000000   0.000000
# 53289   0.798511   0.000000   0.761074   0.000000   0.000000   0.000000
# 2239    0.452484   0.079478   0.192844   0.031339   0.000000   0.000000
# 2       0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 33146   0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 30399   0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 50415   0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 25883   0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 34759   0.082257   0.193110   0.000000   0.000000   0.000000   0.000000
# 52770   0.236531   0.157464   0.473062   0.000000   0.000000   0.000000
# 38518   0.048469   0.000000   0.048469   0.000000   0.000000   0.000000
# 25461   0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 18605   0.672903   0.000000   0.792932   0.000000   0.000000   0.067771
# 52748   0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 49947   0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 4185    0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 509     0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 14112   0.000000   0.000000   0.245878   0.248848   0.085969   0.051761
# 1433    0.078060   0.000000   1.000000   0.000000   0.000000   0.000000
# 21666   0.996952   0.000000   0.996952   0.000000   0.000000   0.000000
# 51414   0.764074   0.886363   0.061619   0.000000   0.000000   0.000000
# 342     0.357000   0.000000   1.000000   0.000000   0.000000   0.000000
# 1399    0.000000   0.000000   0.000000   0.975913   0.000000   0.000000
# 8992    0.174000   0.000000   0.000000   0.043000   0.957000   0.000000
# 27011   0.020559   0.000000   0.000000   0.000000   0.020559   0.938881
# 34046   0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
#
#        Class11.6
# 61577   0.023380
# 369     0.000000
# 56      0.000000
# 17392   0.000000
# 16564   0.000000
# 342     0.000000
# 7163    0.000000
# 5763    0.062062
# 342     0.000000
# 46730   0.002241
# 24281   0.026481
# 41528   0.000000
# 5455    0.105773
# 53289   0.037437
# 2239    0.193100
# 2       0.000000
# 33146   0.000000
# 30399   0.000000
# 50415   0.000000
# 25883   0.062510
# 34759   0.000000
# 52770   0.039534
# 38518   0.000000
# 25461   0.000000
# 18605   0.123306
# 52748   0.003946
# 49947   0.000000
# 4185    0.000000
# 509     0.000000
# 14112   0.367543
# 1433    0.000000
# 21666   0.000000
# 51414   0.000000
# 342     0.000000
# 1399    0.000000
# 8992    0.000000
# 27011   0.020559
# 34046   0.753082
#
# [38 rows x 38 columns]

# %%
rows, cols = 7, 6

# Make a new figure and define dark themed style
figure = plt.figure(figsize=(20, 20))  # Increased figure size for larger images
plt.style.use('dark_background')

for i in range(1, len(maxxed_df)):
    ax = figure.add_subplot(rows, cols, i)
    filename = f"{maxxed_df['GalaxyID'].iloc[i]}.jpg"
    img = plt.imread(os.path.join(root, filename))
    plt.imshow(img)
    plt.title(f"{wrap_title(classification_names[i], width=15)}: {filename}", fontsize=15)
    plt.axis('off')
    add_subplot_border(ax, width=2, color='white')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Based on these images, which labels do you think will be easy to classify (i.e., which are visually obvious)? Which are subtle and more likely to cause problems?**

# %% [markdown]
# # Question 8

# %%
print(type(training_classifications_df.iloc[:, 1].values))
# Out:
# <class 'numpy.ndarray'>

# %%
cor_mat = np.ndarray((num_labels - 1, num_labels - 1))

for a in range(1, num_labels):
    for b in range(1, num_labels):
        i = training_classifications_df.iloc[:, a].values
        j = training_classifications_df.iloc[:, b].values
        i_mean = np.mean(i)
        j_mean = np.mean(j)
        i_mean_squared = np.mean(np.square(i))
        j_mean_squared = np.mean(np.square(j))
        i_j_mean = np.mean(i * j)
        i_var = i_mean_squared - i_mean**2
        j_var = j_mean_squared - j_mean**2
        i_j_cov = i_j_mean - i_mean*j_mean
        correlation = i_j_cov/np.sqrt(i_var*j_var)
        cor_mat[a-1, b-1] = correlation

# %%
# nice way to see all values in correlation matrix in pandas DataFrame
vis_cols = [classification_names[i+1] for i in range(cor_mat.shape[1])]
vis_df = pd.DataFrame(cor_mat, columns=vis_cols, index=vis_cols)

# %%
vis_df
# Out:
#                                                     Amount of Smoothness for a disk  \
# Amount of Smoothness for a disk                                            1.000000
# Signs of features or a disk                                               -0.992416
# Classified as Star or Artifact                                             0.280863
# Disk can be viewed edge-on                                                -0.324072
# Disk cannot be viewed edge-on                                             -0.746400
# Bar or feature through centre of galaxy detected                          -0.481550
# Bar or feautre through centre of galaxy not det...                        -0.564992
# Signs of a spiral arm pattern                                             -0.670888
# No signs of a spiral arm pattern                                          -0.187805
# No bulge                                                                  -0.229011
# Just noticeable bulge                                                     -0.604714
# Obvious bulge                                                             -0.442142
# Dominant bulge                                                            -0.152129
# Odd features in image                                                     -0.262177
# No odd features in image                                                   0.262177
# Completely round                                                           0.629156
# In-between round and cigar                                                 0.617418
# Cigar-shaped                                                              -0.000949
# Presence of Ring                                                          -0.253277
# Presence of lens or arc                                                    0.060418
# Disturbed galaxy                                                          -0.205088
# Irregular galaxy                                                          -0.234141
# Presence of other odd features                                             0.013934
# Merger galaxies                                                           -0.048579
# Presence of dust lane                                                     -0.079763
# Rounded bulge at centre                                                   -0.298510
# Boxy bulge at centre                                                      -0.211762
# No bulge at centre                                                        -0.200730
# Tight spiral arms                                                         -0.508271
# Medium spiral arms                                                        -0.568344
# Loose spiral arms                                                         -0.384315
# 1 spiral arm                                                              -0.223538
# 2 spiral arms                                                             -0.518724
# 3 spiral arms                                                             -0.308240
# 4 spiral arms                                                             -0.234735
# More than 4 spiral arms                                                   -0.166207
# Can't tell if any spiral arms exist                                       -0.404101
#
#                                                     Signs of features or a disk  \
# Amount of Smoothness for a disk                                       -0.992416
# Signs of features or a disk                                            1.000000
# Classified as Star or Artifact                                        -0.396710
# Disk can be viewed edge-on                                             0.332616
# Disk cannot be viewed edge-on                                          0.747833
# Bar or feature through centre of galaxy detected                       0.481963
# Bar or feautre through centre of galaxy not det...                     0.566443
# Signs of a spiral arm pattern                                          0.671806
# No signs of a spiral arm pattern                                       0.188752
# No bulge                                                               0.218291
# Just noticeable bulge                                                  0.608157
# Obvious bulge                                                          0.447578
# Dominant bulge                                                         0.147603
# Odd features in image                                                  0.235267
# No odd features in image                                              -0.235267
# Completely round                                                      -0.636155
# In-between round and cigar                                            -0.607296
# Cigar-shaped                                                           0.015762
# Presence of Ring                                                       0.255936
# Presence of lens or arc                                               -0.067997
# Disturbed galaxy                                                       0.197832
# Irregular galaxy                                                       0.217267
# Presence of other odd features                                        -0.045236
# Merger galaxies                                                        0.034075
# Presence of dust lane                                                  0.078371
# Rounded bulge at centre                                                0.306335
# Boxy bulge at centre                                                   0.215769
# No bulge at centre                                                     0.206699
# Tight spiral arms                                                      0.512074
# Medium spiral arms                                                     0.568195
# Loose spiral arms                                                      0.381616
# 1 spiral arm                                                           0.221152
# 2 spiral arms                                                          0.518735
# 3 spiral arms                                                          0.307934
# 4 spiral arms                                                          0.234663
# More than 4 spiral arms                                                0.166432
# Can't tell if any spiral arms exist                                    0.407822
#
#                                                     Classified as Star or Artifact  \
# Amount of Smoothness for a disk                                           0.280863
# Signs of features or a disk                                              -0.396710
# Classified as Star or Artifact                                            1.000000
# Disk can be viewed edge-on                                               -0.176915
# Disk cannot be viewed edge-on                                            -0.265020
# Bar or feature through centre of galaxy detected                         -0.166986
# Bar or feautre through centre of galaxy not det...                       -0.203469
# Signs of a spiral arm pattern                                            -0.235320
# No signs of a spiral arm pattern                                         -0.071268
# No bulge                                                                  0.005816
# Just noticeable bulge                                                    -0.232529
# Obvious bulge                                                            -0.192799
# Dominant bulge                                                           -0.016395
# Odd features in image                                                     0.120941
# No odd features in image                                                 -0.120941
# Completely round                                                          0.268610
# In-between round and cigar                                                0.130939
# Cigar-shaped                                                             -0.115977
# Presence of Ring                                                         -0.106888
# Presence of lens or arc                                                   0.079722
# Disturbed galaxy                                                         -0.013092
# Irregular galaxy                                                          0.052126
# Presence of other odd features                                            0.249125
# Merger galaxies                                                           0.096720
# Presence of dust lane                                                    -0.016256
# Rounded bulge at centre                                                  -0.162603
# Boxy bulge at centre                                                     -0.103303
# No bulge at centre                                                       -0.114871
# Tight spiral arms                                                        -0.202544
# Medium spiral arms                                                       -0.192115
# Loose spiral arms                                                        -0.109625
# 1 spiral arm                                                             -0.057388
# 2 spiral arms                                                            -0.176487
# 3 spiral arms                                                            -0.102430
# 4 spiral arms                                                            -0.079270
# More than 4 spiral arms                                                  -0.058281
# Can't tell if any spiral arms exist                                      -0.166477
#
#                                                     Disk can be viewed edge-on  \
# Amount of Smoothness for a disk                                      -0.324072
# Signs of features or a disk                                           0.332616
# Classified as Star or Artifact                                       -0.176915
# Disk can be viewed edge-on                                            1.000000
# Disk cannot be viewed edge-on                                        -0.377346
# Bar or feature through centre of galaxy detected                     -0.140077
# Bar or feautre through centre of galaxy not det...                   -0.359635
# Signs of a spiral arm pattern                                        -0.219080
# No signs of a spiral arm pattern                                     -0.285599
# No bulge                                                             -0.080338
# Just noticeable bulge                                                -0.229661
# Obvious bulge                                                        -0.285051
# Dominant bulge                                                       -0.187159
# Odd features in image                                                -0.121750
# No odd features in image                                              0.121750
# Completely round                                                     -0.325562
# In-between round and cigar                                           -0.318850
# Cigar-shaped                                                          0.495675
# Presence of Ring                                                     -0.086070
# Presence of lens or arc                                              -0.079654
# Disturbed galaxy                                                     -0.057483
# Irregular galaxy                                                     -0.091463
# Presence of other odd features                                       -0.061370
# Merger galaxies                                                      -0.058464
# Presence of dust lane                                                 0.225934
# Rounded bulge at centre                                               0.878543
# Boxy bulge at centre                                                  0.644993
# No bulge at centre                                                    0.682327
# Tight spiral arms                                                    -0.189016
# Medium spiral arms                                                   -0.185096
# Loose spiral arms                                                    -0.092647
# 1 spiral arm                                                         -0.096486
# 2 spiral arms                                                        -0.140464
# 3 spiral arms                                                        -0.100969
# 4 spiral arms                                                        -0.075473
# More than 4 spiral arms                                              -0.067365
# Can't tell if any spiral arms exist                                  -0.168409
#
#                                                     Disk cannot be viewed edge-on  \
# Amount of Smoothness for a disk                                         -0.746400
# Signs of features or a disk                                              0.747833
# Classified as Star or Artifact                                          -0.265020
# Disk can be viewed edge-on                                              -0.377346
# Disk cannot be viewed edge-on                                            1.000000
# Bar or feature through centre of galaxy detected                         0.571890
# Bar or feautre through centre of galaxy not det...                       0.809411
# Signs of a spiral arm pattern                                            0.813928
# No signs of a spiral arm pattern                                         0.386405
# No bulge                                                                 0.270914
# Just noticeable bulge                                                    0.758875
# Obvious bulge                                                            0.640182
# Dominant bulge                                                           0.276698
# Odd features in image                                                    0.316737
# No odd features in image                                                -0.316737
# Completely round                                                        -0.395509
# In-between round and cigar                                              -0.371894
# Cigar-shaped                                                            -0.333462
# Presence of Ring                                                         0.311915
# Presence of lens or arc                                                 -0.010699
# Disturbed galaxy                                                         0.234735
# Irregular galaxy                                                         0.277740
# Presence of other odd features                                          -0.001218
# Merger galaxies                                                          0.074618
# Presence of dust lane                                                   -0.082092
# Rounded bulge at centre                                                 -0.317652
# Boxy bulge at centre                                                    -0.242173
# No bulge at centre                                                      -0.277362
# Tight spiral arms                                                        0.635910
# Medium spiral arms                                                       0.688260
# Loose spiral arms                                                        0.439961
# 1 spiral arm                                                             0.285091
# 2 spiral arms                                                            0.608272
# 3 spiral arms                                                            0.373465
# 4 spiral arms                                                            0.283567
# More than 4 spiral arms                                                  0.210857
# Can't tell if any spiral arms exist                                      0.519029
#
#                                                     Bar or feature through centre of galaxy detected  \
# Amount of Smoothness for a disk                                                            -0.481550
# Signs of features or a disk                                                                 0.481963
# Classified as Star or Artifact                                                             -0.166986
# Disk can be viewed edge-on                                                                 -0.140077
# Disk cannot be viewed edge-on                                                               0.571890
# Bar or feature through centre of galaxy detected                                            1.000000
# Bar or feautre through centre of galaxy not det...                                         -0.018839
# Signs of a spiral arm pattern                                                               0.549446
# No signs of a spiral arm pattern                                                            0.087674
# No bulge                                                                                    0.099202
# Just noticeable bulge                                                                       0.402144
# Obvious bulge                                                                               0.429009
# Dominant bulge                                                                              0.152676
# Odd features in image                                                                       0.164661
# No odd features in image                                                                   -0.164661
# Completely round                                                                           -0.269298
# In-between round and cigar                                                                 -0.252788
# Cigar-shaped                                                                               -0.159441
# Presence of Ring                                                                            0.252414
# Presence of lens or arc                                                                    -0.015988
# Disturbed galaxy                                                                            0.135799
# Irregular galaxy                                                                            0.109254
# Presence of other odd features                                                             -0.036109
# Merger galaxies                                                                             0.002783
# Presence of dust lane                                                                      -0.026764
# Rounded bulge at centre                                                                    -0.112865
# Boxy bulge at centre                                                                       -0.080790
# No bulge at centre                                                                         -0.113586
# Tight spiral arms                                                                           0.298747
# Medium spiral arms                                                                          0.516972
# Loose spiral arms                                                                           0.413607
# 1 spiral arm                                                                                0.114720
# 2 spiral arms                                                                               0.597296
# 3 spiral arms                                                                               0.165413
# 4 spiral arms                                                                               0.121268
# More than 4 spiral arms                                                                     0.067495
# Can't tell if any spiral arms exist                                                         0.156307
#
#                                                     Bar or feautre through centre of galaxy not detected  \
# Amount of Smoothness for a disk                                                             -0.564992
# Signs of features or a disk                                                                  0.566443
# Classified as Star or Artifact                                                              -0.203469
# Disk can be viewed edge-on                                                                  -0.359635
# Disk cannot be viewed edge-on                                                                0.809411
# Bar or feature through centre of galaxy detected                                            -0.018839
# Bar or feautre through centre of galaxy not det...                                           1.000000
# Signs of a spiral arm pattern                                                                0.598692
# No signs of a spiral arm pattern                                                             0.408190
# No bulge                                                                                     0.259177
# Just noticeable bulge                                                                        0.637041
# Obvious bulge                                                                                0.473145
# Dominant bulge                                                                               0.227945
# Odd features in image                                                                        0.268166
# No odd features in image                                                                    -0.268166
# Completely round                                                                            -0.289268
# In-between round and cigar                                                                  -0.272306
# Cigar-shaped                                                                                -0.292288
# Presence of Ring                                                                             0.199470
# Presence of lens or arc                                                                     -0.001595
# Disturbed galaxy                                                                             0.188883
# Irregular galaxy                                                                             0.260300
# Presence of other odd features                                                               0.024365
# Merger galaxies                                                                              0.088953
# Presence of dust lane                                                                       -0.080895
# Rounded bulge at centre                                                                     -0.306361
# Boxy bulge at centre                                                                        -0.237328
# No bulge at centre                                                                          -0.256739
# Tight spiral arms                                                                            0.561189
# Medium spiral arms                                                                           0.468774
# Loose spiral arms                                                                            0.240141
# 1 spiral arm                                                                                 0.265346
# 2 spiral arms                                                                                0.313783
# 3 spiral arms                                                                                0.336768
# 4 spiral arms                                                                                0.258801
# More than 4 spiral arms                                                                      0.208677
# Can't tell if any spiral arms exist                                                          0.520701
#
#                                                     Signs of a spiral arm pattern  \
# Amount of Smoothness for a disk                                         -0.670888
# Signs of features or a disk                                              0.671806
# Classified as Star or Artifact                                          -0.235320
# Disk can be viewed edge-on                                              -0.219080
# Disk cannot be viewed edge-on                                            0.813928
# Bar or feature through centre of galaxy detected                         0.549446
# Bar or feautre through centre of galaxy not det...                       0.598692
# Signs of a spiral arm pattern                                            1.000000
# No signs of a spiral arm pattern                                        -0.221336
# No bulge                                                                 0.201213
# Just noticeable bulge                                                    0.713401
# Obvious bulge                                                            0.444633
# Dominant bulge                                                           0.176050
# Odd features in image                                                    0.137148
# No odd features in image                                                -0.137148
# Completely round                                                        -0.356358
# In-between round and cigar                                              -0.366189
# Cigar-shaped                                                            -0.235447
# Presence of Ring                                                         0.126500
# Presence of lens or arc                                                 -0.027589
# Disturbed galaxy                                                         0.228564
# Irregular galaxy                                                         0.180334
# Presence of other odd features                                          -0.077433
# Merger galaxies                                                          0.007605
# Presence of dust lane                                                   -0.049649
# Rounded bulge at centre                                                 -0.188711
# Boxy bulge at centre                                                    -0.142797
# No bulge at centre                                                      -0.154170
# Tight spiral arms                                                        0.754458
# Medium spiral arms                                                       0.858094
# Loose spiral arms                                                        0.562080
# 1 spiral arm                                                             0.324399
# 2 spiral arms                                                            0.781067
# 3 spiral arms                                                            0.494255
# 4 spiral arms                                                            0.370894
# More than 4 spiral arms                                                  0.275108
# Can't tell if any spiral arms exist                                      0.553689
#
#                                                     No signs of a spiral arm pattern  \
# Amount of Smoothness for a disk                                            -0.187805
# Signs of features or a disk                                                 0.188752
# Classified as Star or Artifact                                             -0.071268
# Disk can be viewed edge-on                                                 -0.285599
# Disk cannot be viewed edge-on                                               0.386405
# Bar or feature through centre of galaxy detected                            0.087674
# Bar or feautre through centre of galaxy not det...                          0.408190
# Signs of a spiral arm pattern                                              -0.221336
# No signs of a spiral arm pattern                                            1.000000
# No bulge                                                                    0.135310
# Just noticeable bulge                                                       0.141251
# Obvious bulge                                                               0.368706
# Dominant bulge                                                              0.184966
# Odd features in image                                                       0.313935
# No odd features in image                                                   -0.313935
# Completely round                                                           -0.098147
# In-between round and cigar                                                 -0.042900
# Cigar-shaped                                                               -0.185952
# Presence of Ring                                                            0.322747
# Presence of lens or arc                                                     0.025841
# Disturbed galaxy                                                            0.031158
# Irregular galaxy                                                            0.179914
# Presence of other odd features                                              0.120885
# Merger galaxies                                                             0.113178
# Presence of dust lane                                                      -0.058976
# Rounded bulge at centre                                                    -0.233612
# Boxy bulge at centre                                                       -0.179805
# No bulge at centre                                                         -0.220818
# Tight spiral arms                                                          -0.130335
# Medium spiral arms                                                         -0.206993
# Loose spiral arms                                                          -0.153837
# 1 spiral arm                                                               -0.036460
# 2 spiral arms                                                              -0.218973
# 3 spiral arms                                                              -0.157777
# 4 spiral arms                                                              -0.112835
# More than 4 spiral arms                                                    -0.082815
# Can't tell if any spiral arms exist                                        -0.007794
#
#                                                     No bulge  ...  \
# Amount of Smoothness for a disk                    -0.229011  ...
# Signs of features or a disk                         0.218291  ...
# Classified as Star or Artifact                      0.005816  ...
# Disk can be viewed edge-on                         -0.080338  ...
# Disk cannot be viewed edge-on                       0.270914  ...
# Bar or feature through centre of galaxy detected    0.099202  ...
# Bar or feautre through centre of galaxy not det...  0.259177  ...
# Signs of a spiral arm pattern                       0.201213  ...
# No signs of a spiral arm pattern                    0.135310  ...
# No bulge                                            1.000000  ...
# Just noticeable bulge                               0.190296  ...
# Obvious bulge                                      -0.230142  ...
# Dominant bulge                                     -0.012989  ...
# Odd features in image                               0.211064  ...
# No odd features in image                           -0.211064  ...
# Completely round                                   -0.189312  ...
# In-between round and cigar                         -0.085952  ...
# Cigar-shaped                                       -0.010383  ...
# Presence of Ring                                   -0.076209  ...
# Presence of lens or arc                            -0.067095  ...
# Disturbed galaxy                                    0.179162  ...
# Irregular galaxy                                    0.468584  ...
# Presence of other odd features                      0.087562  ...
# Merger galaxies                                     0.020628  ...
# Presence of dust lane                               0.003350  ...
# Rounded bulge at centre                            -0.111055  ...
# Boxy bulge at centre                               -0.060247  ...
# No bulge at centre                                  0.005157  ...
# Tight spiral arms                                   0.130885  ...
# Medium spiral arms                                  0.164744  ...
# Loose spiral arms                                   0.154671  ...
# 1 spiral arm                                        0.114245  ...
# 2 spiral arms                                       0.122023  ...
# 3 spiral arms                                       0.091713  ...
# 4 spiral arms                                       0.066294  ...
# More than 4 spiral arms                             0.037841  ...
# Can't tell if any spiral arms exist                 0.164850  ...
#
#                                                     No bulge at centre  \
# Amount of Smoothness for a disk                              -0.200730
# Signs of features or a disk                                   0.206699
# Classified as Star or Artifact                               -0.114871
# Disk can be viewed edge-on                                    0.682327
# Disk cannot be viewed edge-on                                -0.277362
# Bar or feature through centre of galaxy detected             -0.113586
# Bar or feautre through centre of galaxy not det...           -0.256739
# Signs of a spiral arm pattern                                -0.154170
# No signs of a spiral arm pattern                             -0.220818
# No bulge                                                      0.005157
# Just noticeable bulge                                        -0.158841
# Obvious bulge                                                -0.245689
# Dominant bulge                                               -0.154347
# Odd features in image                                        -0.104937
# No odd features in image                                      0.104937
# Completely round                                             -0.229397
# In-between round and cigar                                   -0.252610
# Cigar-shaped                                                  0.474798
# Presence of Ring                                             -0.080268
# Presence of lens or arc                                      -0.071472
# Disturbed galaxy                                             -0.047525
# Irregular galaxy                                             -0.051102
# Presence of other odd features                               -0.057239
# Merger galaxies                                              -0.053961
# Presence of dust lane                                         0.158604
# Rounded bulge at centre                                       0.280494
# Boxy bulge at centre                                          0.214930
# No bulge at centre                                            1.000000
# Tight spiral arms                                            -0.129898
# Medium spiral arms                                           -0.130281
# Loose spiral arms                                            -0.069696
# 1 spiral arm                                                 -0.068480
# 2 spiral arms                                                -0.103461
# 3 spiral arms                                                -0.070256
# 4 spiral arms                                                -0.051982
# More than 4 spiral arms                                      -0.046561
# Can't tell if any spiral arms exist                          -0.111093
#
#                                                     Tight spiral arms  \
# Amount of Smoothness for a disk                             -0.508271
# Signs of features or a disk                                  0.512074
# Classified as Star or Artifact                              -0.202544
# Disk can be viewed edge-on                                  -0.189016
# Disk cannot be viewed edge-on                                0.635910
# Bar or feature through centre of galaxy detected             0.298747
# Bar or feautre through centre of galaxy not det...           0.561189
# Signs of a spiral arm pattern                                0.754458
# No signs of a spiral arm pattern                            -0.130335
# No bulge                                                     0.130885
# Just noticeable bulge                                        0.588983
# Obvious bulge                                                0.336490
# Dominant bulge                                               0.107352
# Odd features in image                                        0.030109
# No odd features in image                                    -0.030109
# Completely round                                            -0.265909
# In-between round and cigar                                  -0.275586
# Cigar-shaped                                                -0.190785
# Presence of Ring                                             0.142359
# Presence of lens or arc                                     -0.024976
# Disturbed galaxy                                             0.098252
# Irregular galaxy                                             0.044149
# Presence of other odd features                              -0.093021
# Merger galaxies                                             -0.057066
# Presence of dust lane                                       -0.040343
# Rounded bulge at centre                                     -0.163832
# Boxy bulge at centre                                        -0.127543
# No bulge at centre                                          -0.129898
# Tight spiral arms                                            1.000000
# Medium spiral arms                                           0.464205
# Loose spiral arms                                            0.053783
# 1 spiral arm                                                 0.227990
# 2 spiral arms                                                0.388897
# 3 spiral arms                                                0.425218
# 4 spiral arms                                                0.363443
# More than 4 spiral arms                                      0.334458
# Can't tell if any spiral arms exist                          0.681317
#
#                                                     Medium spiral arms  \
# Amount of Smoothness for a disk                              -0.568344
# Signs of features or a disk                                   0.568195
# Classified as Star or Artifact                               -0.192115
# Disk can be viewed edge-on                                   -0.185096
# Disk cannot be viewed edge-on                                 0.688260
# Bar or feature through centre of galaxy detected              0.516972
# Bar or feautre through centre of galaxy not det...            0.468774
# Signs of a spiral arm pattern                                 0.858094
# No signs of a spiral arm pattern                             -0.206993
# No bulge                                                      0.164744
# Just noticeable bulge                                         0.606687
# Obvious bulge                                                 0.380669
# Dominant bulge                                                0.131734
# Odd features in image                                         0.108987
# No odd features in image                                     -0.108987
# Completely round                                             -0.298673
# In-between round and cigar                                   -0.312344
# Cigar-shaped                                                 -0.202259
# Presence of Ring                                              0.094053
# Presence of lens or arc                                      -0.026062
# Disturbed galaxy                                              0.207109
# Irregular galaxy                                              0.156833
# Presence of other odd features                               -0.060745
# Merger galaxies                                              -0.009225
# Presence of dust lane                                        -0.042137
# Rounded bulge at centre                                      -0.159887
# Boxy bulge at centre                                         -0.118961
# No bulge at centre                                           -0.130281
# Tight spiral arms                                             0.464205
# Medium spiral arms                                            1.000000
# Loose spiral arms                                             0.379096
# 1 spiral arm                                                  0.234404
# 2 spiral arms                                                 0.730892
# 3 spiral arms                                                 0.468403
# 4 spiral arms                                                 0.322079
# More than 4 spiral arms                                       0.183067
# Can't tell if any spiral arms exist                           0.376272
#
#                                                     Loose spiral arms  \
# Amount of Smoothness for a disk                             -0.384315
# Signs of features or a disk                                  0.381616
# Classified as Star or Artifact                              -0.109625
# Disk can be viewed edge-on                                  -0.092647
# Disk cannot be viewed edge-on                                0.439961
# Bar or feature through centre of galaxy detected             0.413607
# Bar or feautre through centre of galaxy not det...           0.240141
# Signs of a spiral arm pattern                                0.562080
# No signs of a spiral arm pattern                            -0.153837
# No bulge                                                     0.154671
# Just noticeable bulge                                        0.334770
# Obvious bulge                                                0.249634
# Dominant bulge                                               0.163176
# Odd features in image                                        0.196129
# No odd features in image                                    -0.196129
# Completely round                                            -0.214580
# In-between round and cigar                                  -0.209470
# Cigar-shaped                                                -0.112878
# Presence of Ring                                             0.023117
# Presence of lens or arc                                     -0.006096
# Disturbed galaxy                                             0.221103
# Irregular galaxy                                             0.232268
# Presence of other odd features                              -0.001134
# Merger galaxies                                              0.117835
# Presence of dust lane                                       -0.024360
# Rounded bulge at centre                                     -0.077692
# Boxy bulge at centre                                        -0.056431
# No bulge at centre                                          -0.069696
# Tight spiral arms                                            0.053783
# Medium spiral arms                                           0.379096
# Loose spiral arms                                            1.000000
# 1 spiral arm                                                 0.268425
# 2 spiral arms                                                0.645710
# 3 spiral arms                                                0.139473
# 4 spiral arms                                                0.081348
# More than 4 spiral arms                                      0.044207
# Can't tell if any spiral arms exist                          0.066081
#
#                                                     1 spiral arm  \
# Amount of Smoothness for a disk                        -0.223538
# Signs of features or a disk                             0.221152
# Classified as Star or Artifact                         -0.057388
# Disk can be viewed edge-on                             -0.096486
# Disk cannot be viewed edge-on                           0.285091
# Bar or feature through centre of galaxy detected        0.114720
# Bar or feautre through centre of galaxy not det...      0.265346
# Signs of a spiral arm pattern                           0.324399
# No signs of a spiral arm pattern                       -0.036460
# No bulge                                                0.114245
# Just noticeable bulge                                   0.193961
# Obvious bulge                                           0.161248
# Dominant bulge                                          0.160268
# Odd features in image                                   0.209493
# No odd features in image                               -0.209493
# Completely round                                       -0.112509
# In-between round and cigar                             -0.115239
# Cigar-shaped                                           -0.105168
# Presence of Ring                                        0.056178
# Presence of lens or arc                                 0.080688
# Disturbed galaxy                                        0.183631
# Irregular galaxy                                        0.204373
# Presence of other odd features                          0.012281
# Merger galaxies                                         0.119461
# Presence of dust lane                                  -0.019025
# Rounded bulge at centre                                -0.083774
# Boxy bulge at centre                                   -0.059013
# No bulge at centre                                     -0.068480
# Tight spiral arms                                       0.227990
# Medium spiral arms                                      0.234404
# Loose spiral arms                                       0.268425
# 1 spiral arm                                            1.000000
# 2 spiral arms                                           0.120109
# 3 spiral arms                                           0.045476
# 4 spiral arms                                          -0.000422
# More than 4 spiral arms                                -0.009140
# Can't tell if any spiral arms exist                     0.133345
#
#                                                     2 spiral arms  \
# Amount of Smoothness for a disk                         -0.518724
# Signs of features or a disk                              0.518735
# Classified as Star or Artifact                          -0.176487
# Disk can be viewed edge-on                              -0.140464
# Disk cannot be viewed edge-on                            0.608272
# Bar or feature through centre of galaxy detected         0.597296
# Bar or feautre through centre of galaxy not det...       0.313783
# Signs of a spiral arm pattern                            0.781067
# No signs of a spiral arm pattern                        -0.218973
# No bulge                                                 0.122023
# Just noticeable bulge                                    0.500139
# Obvious bulge                                            0.374750
# Dominant bulge                                           0.151088
# Odd features in image                                    0.097725
# No odd features in image                                -0.097725
# Completely round                                        -0.273879
# In-between round and cigar                              -0.292633
# Cigar-shaped                                            -0.167047
# Presence of Ring                                         0.109017
# Presence of lens or arc                                 -0.033395
# Disturbed galaxy                                         0.158984
# Irregular galaxy                                         0.093604
# Presence of other odd features                          -0.054256
# Merger galaxies                                          0.018356
# Presence of dust lane                                   -0.034963
# Rounded bulge at centre                                 -0.118440
# Boxy bulge at centre                                    -0.088890
# No bulge at centre                                      -0.103461
# Tight spiral arms                                        0.388897
# Medium spiral arms                                       0.730892
# Loose spiral arms                                        0.645710
# 1 spiral arm                                             0.120109
# 2 spiral arms                                            1.000000
# 3 spiral arms                                            0.161764
# 4 spiral arms                                            0.061650
# More than 4 spiral arms                                 -0.000690
# Can't tell if any spiral arms exist                      0.089197
#
#                                                     3 spiral arms  \
# Amount of Smoothness for a disk                         -0.308240
# Signs of features or a disk                              0.307934
# Classified as Star or Artifact                          -0.102430
# Disk can be viewed edge-on                              -0.100969
# Disk cannot be viewed edge-on                            0.373465
# Bar or feature through centre of galaxy detected         0.165413
# Bar or feautre through centre of galaxy not det...       0.336768
# Signs of a spiral arm pattern                            0.494255
# No signs of a spiral arm pattern                        -0.157777
# No bulge                                                 0.091713
# Just noticeable bulge                                    0.389479
# Obvious bulge                                            0.159440
# Dominant bulge                                           0.016557
# Odd features in image                                    0.023505
# No odd features in image                                -0.023505
# Completely round                                        -0.143700
# In-between round and cigar                              -0.185677
# Cigar-shaped                                            -0.117409
# Presence of Ring                                        -0.007762
# Presence of lens or arc                                 -0.026583
# Disturbed galaxy                                         0.130042
# Irregular galaxy                                         0.096624
# Presence of other odd features                          -0.048324
# Merger galaxies                                         -0.026168
# Presence of dust lane                                   -0.021730
# Rounded bulge at centre                                 -0.088612
# Boxy bulge at centre                                    -0.061963
# No bulge at centre                                      -0.070256
# Tight spiral arms                                        0.425218
# Medium spiral arms                                       0.468403
# Loose spiral arms                                        0.139473
# 1 spiral arm                                             0.045476
# 2 spiral arms                                            0.161764
# 3 spiral arms                                            1.000000
# 4 spiral arms                                            0.355858
# More than 4 spiral arms                                  0.152566
# Can't tell if any spiral arms exist                      0.193500
#
#                                                     4 spiral arms  \
# Amount of Smoothness for a disk                         -0.234735
# Signs of features or a disk                              0.234663
# Classified as Star or Artifact                          -0.079270
# Disk can be viewed edge-on                              -0.075473
# Disk cannot be viewed edge-on                            0.283567
# Bar or feature through centre of galaxy detected         0.121268
# Bar or feautre through centre of galaxy not det...       0.258801
# Signs of a spiral arm pattern                            0.370894
# No signs of a spiral arm pattern                        -0.112835
# No bulge                                                 0.066294
# Just noticeable bulge                                    0.298129
# Obvious bulge                                            0.123621
# Dominant bulge                                           0.002087
# Odd features in image                                    0.000240
# No odd features in image                                -0.000240
# Completely round                                        -0.110359
# In-between round and cigar                              -0.140966
# Cigar-shaped                                            -0.088253
# Presence of Ring                                        -0.000217
# Presence of lens or arc                                 -0.029258
# Disturbed galaxy                                         0.065760
# Irregular galaxy                                         0.055473
# Presence of other odd features                          -0.036530
# Merger galaxies                                         -0.030772
# Presence of dust lane                                   -0.016364
# Rounded bulge at centre                                 -0.066168
# Boxy bulge at centre                                    -0.047934
# No bulge at centre                                      -0.051982
# Tight spiral arms                                        0.363443
# Medium spiral arms                                       0.322079
# Loose spiral arms                                        0.081348
# 1 spiral arm                                            -0.000422
# 2 spiral arms                                            0.061650
# 3 spiral arms                                            0.355858
# 4 spiral arms                                            1.000000
# More than 4 spiral arms                                  0.343152
# Can't tell if any spiral arms exist                      0.181248
#
#                                                     More than 4 spiral arms  \
# Amount of Smoothness for a disk                                   -0.166207
# Signs of features or a disk                                        0.166432
# Classified as Star or Artifact                                    -0.058281
# Disk can be viewed edge-on                                        -0.067365
# Disk cannot be viewed edge-on                                      0.210857
# Bar or feature through centre of galaxy detected                   0.067495
# Bar or feautre through centre of galaxy not det...                 0.208677
# Signs of a spiral arm pattern                                      0.275108
# No signs of a spiral arm pattern                                  -0.082815
# No bulge                                                           0.037841
# Just noticeable bulge                                              0.216938
# Obvious bulge                                                      0.098897
# Dominant bulge                                                     0.012468
# Odd features in image                                             -0.015837
# No odd features in image                                           0.015837
# Completely round                                                  -0.074380
# In-between round and cigar                                        -0.098116
# Cigar-shaped                                                      -0.073941
# Presence of Ring                                                  -0.007096
# Presence of lens or arc                                           -0.018136
# Disturbed galaxy                                                   0.034681
# Irregular galaxy                                                   0.017091
# Presence of other odd features                                    -0.026470
# Merger galaxies                                                   -0.026369
# Presence of dust lane                                             -0.013144
# Rounded bulge at centre                                           -0.058914
# Boxy bulge at centre                                              -0.042889
# No bulge at centre                                                -0.046561
# Tight spiral arms                                                  0.334458
# Medium spiral arms                                                 0.183067
# Loose spiral arms                                                  0.044207
# 1 spiral arm                                                      -0.009140
# 2 spiral arms                                                     -0.000690
# 3 spiral arms                                                      0.152566
# 4 spiral arms                                                      0.343152
# More than 4 spiral arms                                            1.000000
# Can't tell if any spiral arms exist                                0.173584
#
#                                                     Can't tell if any spiral arms exist
# Amount of Smoothness for a disk                                               -0.404101
# Signs of features or a disk                                                    0.407822
# Classified as Star or Artifact                                                -0.166477
# Disk can be viewed edge-on                                                    -0.168409
# Disk cannot be viewed edge-on                                                  0.519029
# Bar or feature through centre of galaxy detected                               0.156307
# Bar or feautre through centre of galaxy not det...                             0.520701
# Signs of a spiral arm pattern                                                  0.553689
# No signs of a spiral arm pattern                                              -0.007794
# No bulge                                                                       0.164850
# Just noticeable bulge                                                          0.474147
# Obvious bulge                                                                  0.248839
# Dominant bulge                                                                 0.101659
# Odd features in image                                                          0.076751
# No odd features in image                                                      -0.076751
# Completely round                                                              -0.243086
# In-between round and cigar                                                    -0.188709
# Cigar-shaped                                                                  -0.142614
# Presence of Ring                                                               0.119443
# Presence of lens or arc                                                       -0.019053
# Disturbed galaxy                                                               0.114272
# Irregular galaxy                                                               0.124718
# Presence of other odd features                                                -0.061459
# Merger galaxies                                                               -0.034674
# Presence of dust lane                                                         -0.035619
# Rounded bulge at centre                                                       -0.147606
# Boxy bulge at centre                                                          -0.119678
# No bulge at centre                                                            -0.111093
# Tight spiral arms                                                              0.681317
# Medium spiral arms                                                             0.376272
# Loose spiral arms                                                              0.066081
# 1 spiral arm                                                                   0.133345
# 2 spiral arms                                                                  0.089197
# 3 spiral arms                                                                  0.193500
# 4 spiral arms                                                                  0.181248
# More than 4 spiral arms                                                        0.173584
# Can't tell if any spiral arms exist                                            1.000000
#
# [37 rows x 37 columns]

# %%
# Create a heatmap using Matplotlib
plt.figure(figsize=(15, 15))
plt.imshow(vis_df.values, cmap='coolwarm', aspect='auto')

# Add color bar
plt.colorbar(label='Value')

# Set ticks and labels
plt.xticks(ticks=np.arange(len(vis_df.columns)), labels=vis_df.columns, rotation=90)
plt.yticks(ticks=np.arange(len(vis_df.index)), labels=vis_df.index)

"""
# Add text annotations
for i in range(len(vis_df.index)):
    for j in range(len(vis_df.columns)):
        plt.text(j, i, f'{vis_df.iloc[i, j]:.1f}', ha='center', va='center', color='black')
"""

# Add title
plt.title("Heatmap of vis_df Values", fontsize=16)
plt.xlabel("Columns", fontsize=12)
plt.ylabel("Rows", fontsize=12)

# Show plot
plt.tight_layout()
plt.show()

# %% [markdown]
# # Question 9

# %% [markdown]
# We are going to build a model to predict classifications (labels) based on images. To train the model, we will have to repeatedly compare predictions for each image in the training set to its known labels. What is the minimum amount of memory it would take (within a factor of ∼ 2) to load each image in the training set into memory? Don’t worry (yet) about the memory required to store the model. Hint: You can estimate this by thinking about how many pixels are in the total set of images.
#
# <span style="color: red;">
#     !!!!!!!!!!!!!!!!!!!!!!!!!!!!
#     **DO THISSSSS**
#     !!!!!!!!!!!!!!!!!!!!!!!!!!!!
# </span>

# %% [markdown]
# # Question 10

# %%
def downsize_image(image_path, resize_size=80):
    with Image.open(image_path) as img:
        original_width, original_height = img.size
        new_width = int(original_width / (resize_size ** 0.5))
        new_height = int(original_height / (resize_size ** 0.5))
        left = (original_width - new_width) // 2
        top = (original_height - new_height) // 2
        right = left + new_width
        bottom = top + new_height
        cropped = img.crop((left, top, right, bottom))
        downsized_image = cropped.resize((new_width, new_height), Image.Resampling.LANCZOS)
    return np.array(downsized_image)

# Function to split list into chunks
def split_into_batches(lst, n):
    avg = len(lst) // n
    remainder = len(lst) % n
    batches = []
    start = 0
    for i in range(n):
        end = start + avg + (1 if i < remainder else 0)
        batches.append(lst[start:end])
        start = end
    return batches

# %%
plot_example_full = [plt.imread(os.path.join(root, f"{training_classifications_df['GalaxyID'].iloc[i]}.jpg")) for i in range(3)]
plot_example_downsized = [downsize_image(os.path.join(root, f"{training_classifications_df['GalaxyID'].iloc[i]}.jpg"), resize_size=5) for i in range(3)]

# %%
print(len(plot_example_full))
print(len(plot_example_downsized))
# Out:
# 3
# 3

# %%
# Plot a few images before and after downsizing
for i in range(len(plot_example_full)):
    original_image = plot_example_full[i]
    downsized_image = plot_example_downsized[i]
    
    print("Original Image Dimensions: ", original_image.shape)
    print("Downsized Image Dimensions: ", downsized_image.shape)
    
    fig, axs = plt.subplots(1, 2, figsize=(8, 4))
    axs[0].imshow(original_image)
    axs[0].set_title('Original Image')
    axs[0].axis('off')
    
    axs[1].imshow(downsized_image)
    axs[1].set_title('Downsized Image')
    axs[1].axis('off')
    
    plt.show()
    
# delete to save memory
del plot_example_full
del plot_example_downsized
# Out:
# Original Image Dimensions:  (424, 424, 3)
# Downsized Image Dimensions:  (189, 189, 3)
# Original Image Dimensions:  (424, 424, 3)
# Downsized Image Dimensions:  (189, 189, 3)
# Original Image Dimensions:  (424, 424, 3)
# Downsized Image Dimensions:  (189, 189, 3)

# %% [markdown]
# # Question 11

# %%
# Data generator function
def data_generator(batch_files, batch_size):
    current_index = 0
    labels_array = training_classifications_df.iloc[:, 1:].values
    
    for batch in batch_files:
        images = np.array(load(batch))
        
        # images is a numpy array of shape (height, width, channels)
        num_images = len(images)
        
        # Normalize images
        images = images.astype('float32') / 255.0
        
        # Get labels for these images
        batch_labels = labels_array[current_index:current_index + num_images]
        current_index += num_images
        
        # Convert images and labels to tensors
        images = torch.tensor(images, dtype=torch.float32)
        labels = torch.tensor(batch_labels, dtype=torch.float32)
        
        # Permute images to (batch_size, channels, height, width)
        images = images.permute(0, 3, 1, 2)
        
        # Create mini-batches
        dataset_size = len(images)
        num_batches = (dataset_size + batch_size - 1) // batch_size
        
        for i in range(num_batches):
            start_idx = i * batch_size
            end_idx = min(start_idx + batch_size, dataset_size)
            batch_images = images[start_idx:end_idx]
            batch_labels = labels[start_idx:end_idx]
            yield batch_images, batch_labels

# %% [markdown]
# # Question 12

# %%
train_df = training_classifications_df.sample(frac=0.8, random_state=42)
val_df = training_classifications_df.drop(train_df.index)

# %%
# Make a new figure
figure = plt.figure(figsize=(12,12))
rows, cols = 10, 4

for i in range(1, len(classification_names)):
    ax = figure.add_subplot(rows, cols, i)
    train_vals = train_df.iloc[:, i]
    val_vals = val_df.iloc[:, i]
    
    # Plot histograms for training and validation
    plt.hist(train_vals, alpha=0.6, label='Train', bins=10, color='red', density=True)
    plt.hist(val_vals, alpha=0.6, label='Val', bins=10, color='orange', density=True)
    
    # Set the title and labels
    plt.title(wrap_title(classification_names[i], width=25), fontsize=11)
    plt.legend(loc='upper right', fontsize=6)
    
    # Add subplot border
    add_subplot_border(ax, width=1, color='white')

# Adjust layout
plt.subplots_adjust(left=0.1, right=0.9, top=1.7, bottom=0.0, wspace=0.7, hspace=0.5)
plt.show()

# %%
num_batches = 5

# %%
# Get filepaths of all images
train_images = [plt.imread(os.path.join(root, f"{train_df['GalaxyID'].iloc[i]}.jpg")) for i in tqdm(range(len(train_df)), desc="Loading Training Images")]
# Out:
# Loading Training Images: 100%|███████████| 49262/49262 [01:12<00:00, 678.47it/s]

# %%
train_batches = split_into_batches(train_images, num_batches)

# %%
# Process in batches and save to disk
for i, batch in enumerate(train_batches):
    downsized_batch = [downsize_image((os.path.join(root, f"{train_df['GalaxyID'].iloc[i]}.jpg")), resize_size=5) for i in tqdm(range(len(batch)), desc=f"Processing Batch {i+1}")]
    save_path = f"/Volumes/2TB RAKESH/ay128-lab3-storage/downsized_batch_train_{i}.joblib"
    dump(downsized_batch, save_path)
    
    # delete to save memory
    del downsized_batch
    
# delete to save memory
del train_batches
# Out:
# Processing Batch 1: 100%|██████████████████| 9853/9853 [00:11<00:00, 848.08it/s]
# Processing Batch 2: 100%|██████████████████| 9853/9853 [00:10<00:00, 930.45it/s]
# Processing Batch 3: 100%|██████████████████| 9852/9852 [00:10<00:00, 945.33it/s]
# Processing Batch 4: 100%|██████████████████| 9852/9852 [00:10<00:00, 952.08it/s]
# Processing Batch 5: 100%|██████████████████| 9852/9852 [00:10<00:00, 941.82it/s]

# %%
del train_images

# %%
# Get filepaths of all images
val_images = [plt.imread(os.path.join(root, f"{val_df['GalaxyID'].iloc[i]}.jpg")) for i in tqdm(range(len(val_df)), desc="Loading Validation Images")]
# Out:
# Loading Validation Images: 100%|█████████| 12316/12316 [00:19<00:00, 623.61it/s]

# %%
val_batches = split_into_batches(val_images, num_batches)

# %%
# Process in batches and save to disk
for i, batch in enumerate(val_batches):
    downsized_batch = [downsize_image(os.path.join(root, f"{val_df['GalaxyID'].iloc[i]}.jpg"), resize_size=5) for img in tqdm(range(len(batch)), desc=f"Processing Batch {i+1}")]
    save_path = f"/Volumes/2TB RAKESH/ay128-lab3-storage/downsized_batch_val_{i}.joblib"
    dump(downsized_batch, save_path)
    
    # delete to save memory
    del downsized_batch
    
# delete to save memory
del val_batches
# Out:
# Processing Batch 1: 100%|█████████████████| 2464/2464 [00:02<00:00, 1183.68it/s]
# Processing Batch 2: 100%|█████████████████| 2463/2463 [00:02<00:00, 1195.56it/s]
# Processing Batch 3: 100%|█████████████████| 2463/2463 [00:01<00:00, 1272.97it/s]
# Processing Batch 4: 100%|█████████████████| 2463/2463 [00:01<00:00, 1279.62it/s]
# Processing Batch 5: 100%|█████████████████| 2463/2463 [00:02<00:00, 1154.79it/s]

# %%
del val_images

# %% [markdown]
# # Question 13

# %%
# crude guess for train labels
labels_true = np.array([np.array(train_df.iloc[:, i]) for i in range(1, len(classification_names))])
labels_predicted = np.array([np.mean(labels_true[i]) for i in range(len(labels_true))])

# %%
labels_predicted
# Out:
# array([0.4325524 , 0.54215598, 0.02529162, 0.10641663, 0.43573935,
#        0.10228772, 0.33345163, 0.21567748, 0.22006187, 0.04095122,
#        0.18037685, 0.17791076, 0.03650052, 0.23175702, 0.76824298,
#        0.16947329, 0.20821338, 0.05486573, 0.03474187, 0.01334722,
#        0.03284163, 0.04017372, 0.06449302, 0.04233573, 0.00382381,
#        0.06311022, 0.01064247, 0.03266394, 0.09212405, 0.0838378 ,
#        0.03971563, 0.01548132, 0.09366262, 0.01771552, 0.00778526,
#        0.00724342, 0.07378934])

# %%
print("Mean values for the first label cross check:")
print(np.mean(labels_true[0]))
print(labels_predicted[0])
# Out:
# Mean values for the first label cross check:
# 0.4325524004912509
# 0.4325524004912509

# %%
labels_true_train = np.array([train_df.iloc[i][1:] for i in range(len(train_df))])
labels_true_val = np.array([train_df.iloc[i][1:] for i in range(len(val_df))])

# %%
print("Training Set:")
print(len(labels_true_train))
print(len(labels_true_train[39]))
print("")
print("Validation Set:")
print(len(labels_true_val))
print(len(labels_true_val[39]))
# Out:
# Training Set:
# 49262
# 37
#
# Validation Set:
# 12316
# 37

# %%
# finding the RMSE

crude_rmse_train = np.sqrt(
    (1/len(train_df)*len(classification_names))
    *
    np.sum(np.square([labels_true_train[i] - labels_predicted for i in range(len(train_df))])))

crude_rmse_test = np.sqrt(
    (1/len(val_df)*len(classification_names))
    *
    np.sum(np.square([labels_true_val[i] - labels_predicted for i in range(len(val_df))])))

# %%
print(f"Training RMSE: {crude_rmse_train}")
print(f"Validation RMSE: {crude_rmse_test}")
# Out:
# Training RMSE: 6.148029322600515
# Validation RMSE: 6.15305469304878

# %% [markdown]
# # Question 14

# %%
# Swish Function 
class Swish(nn.Module):
    def forward(self, x):
        return x * torch.sigmoid(x)

# %%
class GalaxyClassifier(nn.Module):
    def __init__(self, num_labels):
        super(GalaxyClassifier, self).__init__()
        self.layer1 = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=3, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU()
        )
        self.layer2 = nn.Sequential(
            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU()
        )
        self.layer3 = nn.Sequential(
            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128),
            Swish(),
        )

        self.maxpool = nn.MaxPool2d(2, 2)
        self.connected1 = nn.Linear(8192, 256)
        self.connected2 = nn.Linear(256, 128)
        self.connected3 = nn.Linear(128, num_labels-1)
        self.dropout = nn.Dropout(0.25)
    
    def forward(self, x):
        
        # Layer 1 forward and pooling
        x = self.layer1(x)
        x = self.maxpool(x)
        
        # Layer 2 forward and pooling
        x = self.layer2(x)
        x = self.maxpool(x)
        
        # Layer 3 forward and pooling
        x = self.layer3(x)
        x = self.maxpool(x)
        
        # Fully connected layers
        x = x.contiguous().view(x.size(0), -1)
        x = F.relu(self.connected1(x))
        x = self.dropout(x)
        x = F.log_softmax(self.connected2(x), dim=-1)
        x = self.dropout(x)
        x = torch.sigmoid(self.connected3(x))
        return x

# %%
model = GalaxyClassifier(num_labels=num_labels).to(device)
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.01)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=2, min_lr=1e-6)

# %%
train_batch_files = [f"/Volumes/2TB RAKESH/ay128-lab3-storage/downsized_batch_train_{i}.joblib" for i in range(num_batches)]
val_batch_files = [f"/Volumes/2TB RAKESH/ay128-lab3-storage/downsized_batch_val_{i}.joblib" for i in range(num_batches)]

# %%
num_epochs = 20
batch_size = 128
train_loss = []
val_loss = []

for epoch in tqdm(range(num_epochs)):
    
    # Training the model
    # set the model to train mode
    model.train()
    
    training_loss = 0.0
    training_samples = 0
    
    # get the data to train in batch
    data_gen = data_generator(train_batch_files, batch_size)
    for batch_images, batch_labels in data_gen:
        batch_images = batch_images.to(device)
        batch_labels = batch_labels.to(device)
        
        # Zero the parameter gradients
        optimizer.zero_grad()
        
        # Forward pass
        outputs = model(batch_images)
        
        # Compute loss
        loss = criterion(outputs, batch_labels)
        
        # Backward pass and optimization
        loss.backward()
        optimizer.step()
        
        # Accumulate loss and samples
        training_loss += loss.item()
        training_samples += 1
        
    avg_training_loss = training_loss / training_samples
    train_loss.append(avg_training_loss)
    
    # Validation
    model.eval()  # Set model to evaluation mode
    validation_loss = 0.0
    validation_samples = 0
    with torch.no_grad():
        val_data_gen = data_generator(val_batch_files, batch_size)
        for val_images, val_labels in val_data_gen:
            val_images = val_images.to(device)
            val_labels = val_labels.to(device)
            
            # Forward pass
            outputs = model(val_images)
            
            # Compute loss
            loss = criterion(outputs, val_labels)
            
            # Accumulate loss and samples
            validation_loss += loss.item()
            validation_samples += 1
    
    avg_validation_loss = validation_loss / validation_samples
    val_loss.append(avg_validation_loss)
    
    scheduler.step(avg_validation_loss)
    
    print(f'Epoch [{epoch + 1}/{num_epochs}], Training Loss: {avg_training_loss:.4f}, Validation Loss: {avg_validation_loss:.4f}')

# Save the trained model
cnn_save_path = 'galaxy_classifier.pth'
torch.save({
    'model_state_dict': model.state_dict(),
    'optimizer_state_dict': optimizer.state_dict(),
    'train_loss_hist': train_loss,
    'val_loss_hist': val_loss
}, cnn_save_path)

print(f"Model is saved at {cnn_save_path}!")
# Out:
#   5%|██                                       | 1/20 [04:03<1:17:03, 243.36s/it]
# Epoch [1/20], Training Loss: 0.0598, Validation Loss: 0.0587
#   5%|██                                       | 1/20 [05:08<1:37:33, 308.05s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[65], line 17
#      15 # get the data to train in batch
#      16 data_gen = data_generator(train_batch_files, batch_size)
# ---> 17 for batch_images, batch_labels in data_gen:
#      18     batch_images = batch_images.to(device)
#      19     batch_labels = batch_labels.to(device)
#
# Cell In[23], line 7, in data_generator(batch_files, batch_size)
#       4 labels_array = training_classifications_df.iloc[:, 1:].values
#       6 for batch in batch_files:
# ----> 7     images = np.array(load(batch))
#       9     # images is a numpy array of shape (height, width, channels)
#      10     num_images = len(images)
#
# File ~/anaconda3/envs/astrods/lib/python3.11/site-packages/joblib/numpy_pickle.py:658, in load(filename, mmap_mode)
#     652             if isinstance(fobj, str):
#     653                 # if the returned file object is a string, this means we
#     654                 # try to load a pickle file generated with an version of
#     655                 # Joblib so we load it with joblib compatibility function.
#     656                 return load_compatibility(fobj)
# --> 658             obj = _unpickle(fobj, filename, mmap_mode)
#     659 return obj
#
# File ~/anaconda3/envs/astrods/lib/python3.11/site-packages/joblib/numpy_pickle.py:577, in _unpickle(fobj, filename, mmap_mode)
#     575 obj = None
#     576 try:
# --> 577     obj = unpickler.load()
#     578     if unpickler.compat_mode:
#     579         warnings.warn("The file '%s' has been generated with a "
#     580                       "joblib version less than 0.10. "
#     581                       "Please regenerate this pickle file."
#     582                       % filename,
#     583                       DeprecationWarning, stacklevel=3)
#
# File ~/anaconda3/envs/astrods/lib/python3.11/pickle.py:1213, in _Unpickler.load(self)
#    1211             raise EOFError
#    1212         assert isinstance(key, bytes_types)
# -> 1213         dispatch[key[0]](self)
#    1214 except _Stop as stopinst:
#    1215     return stopinst.value
#
# File ~/anaconda3/envs/astrods/lib/python3.11/site-packages/joblib/numpy_pickle.py:415, in NumpyUnpickler.load_build(self)
#     413 if isinstance(array_wrapper, NDArrayWrapper):
#     414     self.compat_mode = True
# --> 415 self.stack.append(array_wrapper.read(self))
#
# File ~/anaconda3/envs/astrods/lib/python3.11/site-packages/joblib/numpy_pickle.py:252, in NumpyArrayWrapper.read(self, unpickler)
#     250     array = self.read_mmap(unpickler)
#     251 else:
# --> 252     array = self.read_array(unpickler)
#     254 # Manage array subclass case
#     255 if (hasattr(array, '__array_prepare__') and
#     256     self.subclass not in (unpickler.np.ndarray,
#     257                           unpickler.np.memmap)):
#     258     # We need to reconstruct another subclass
#
# File ~/anaconda3/envs/astrods/lib/python3.11/site-packages/joblib/numpy_pickle.py:177, in NumpyArrayWrapper.read_array(self, unpickler)
#     175 read_count = min(max_read_count, count - i)
#     176 read_size = int(read_count * self.dtype.itemsize)
# --> 177 data = _read_bytes(unpickler.file_handle,
#     178                    read_size, "array data")
#     179 array[i:i + read_count] = \
#     180     unpickler.np.frombuffer(data, dtype=self.dtype,
#     181                             count=read_count)
#     182 del data
#
# File ~/anaconda3/envs/astrods/lib/python3.11/site-packages/joblib/numpy_pickle_utils.py:243, in _read_bytes(fp, size, error_template)
#     238 while True:
#     239     # io files (default in python3) return None or raise on
#     240     # would-block, python2 file will truncate, probably nothing can be
#     241     # done about that.  note that regular files can't be non-blocking
#     242     try:
# --> 243         r = fp.read(size - len(data))
#     244         data += r
#     245         if len(r) == 0 or len(data) == size:
#
# KeyboardInterrupt:

# %%
# Plot
plt.figure(figsize=(10, 7))
plt.plot(range(num_epochs), np.sqrt(np.array(train_loss)), label="Training Loss", marker='D')
plt.plot(range(num_epochs), np.sqrt(np.array(val_loss)), label="Validation Loss", marker='D')

# Add annotations for Training Loss
for i, loss in enumerate(np.sqrt(np.array(train_loss))):
    plt.text(i, loss, f"{loss:.3f}", fontsize=8, ha='right', va='bottom')

# Add annotations for Validation Loss
for i, loss in enumerate(np.sqrt(np.array(val_loss))):
    plt.text(i, loss, f"{loss:.3f}", fontsize=8, ha='right', va='top')

# Labels, title, legend, and grid
plt.xlabel("Number of Epochs")
plt.ylabel("RMSE Loss")
plt.title("Loss vs. Epoch")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# # Question 15

# %% [markdown]
# How many total trainable parameters does your model have? In PyTorch, you can count the number of elements in a layer using p.numel(), where p in an element of model.parameters. You can tell whether a parameter is trainable using p.requires_grad(). Does the number of free parameters make you nervous? Explain. Compare it to the number of pixels in your compressed training set.

# %%
total_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f'Total trainable parameters: {total_params}')
# Out:
# Total trainable parameters: 2228773

# %% [markdown]
# # Question 16

# %% [markdown]
# In building your networks, you may have struggled to decide on the right network architecture. How many layers? What kind of pooling? How much dropout? You might also have found that as the size of the network increases, it gets pretty tedious to set up the layers by hand and keep track of their dimension when they meet.
#
# One solution to both of these issues is to use a network architecture that has already been proven to work well for image classification. Check out He et al. 2015, which describes ResNets, one of the most popular networks introduced in computer vision in the last several years. Describe in a few sentences what ResNets are. How are they different from just stacking more and more layers on a CNN?

# %% [markdown]
# # Question 17

# %%
resnet18 = models.resnet18(pretrained=True)
num_ftrs = resnet18.fc.in_features
# Out:
# /Users/rakeshmehta/anaconda3/envs/astrods/lib/python3.11/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /Users/rakeshmehta/anaconda3/envs/astrods/lib/python3.11/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
resnet18.fc = nn.Linear(num_ftrs, num_labels-1)
resnet18 = resnet18.to(device)

for epoch in tqdm(range(num_epochs)):
    resnet18.train()  # Set model to training mode
    training_loss = 0.0
    training_samples = 0
    # Training data generator
    train_data_gen = data_generator(train_batch_files, batch_size)
    for batch_images, batch_labels in train_data_gen:
        batch_images = batch_images.to(device)
        batch_labels = batch_labels.to(device)

        # Zero the parameter gradients
        optimizer.zero_grad()

        # Forward pass
        outputs = resnet18(batch_images)

        # Compute loss
        loss = criterion(outputs, batch_labels)

        # Backward pass and optimization
        loss.backward()
        optimizer.step()

        # Accumulate loss and samples
        training_loss += loss.item()
        training_samples += 1

    avg_training_loss = training_loss / training_samples

    # Validation
    resnet18.eval()  # Set model to evaluation mode
    validation_loss = 0.0
    validation_samples = 0
    with torch.no_grad():
        val_data_gen = data_generator(val_batch_files, batch_size)
        for val_images, val_labels in val_data_gen:
            val_images = val_images.to(device)
            val_labels = val_labels.to(device)

            # Forward pass
            outputs = resnet18(val_images)

            # Compute loss
            loss = criterion(outputs, val_labels)

            # Accumulate loss and samples
            validation_loss += loss.item()
            validation_samples += 1

    avg_validation_loss = validation_loss / validation_samples

    print(f'Epoch [{epoch + 1}/{num_epochs}], Training Loss: {avg_training_loss:.4f}, Validation Loss: {avg_validation_loss:.4f}')

# Save the trained model
torch.save(model.state_dict(), 'galaxy_classifier_resnet18.pth')
# Out:
#   5%|██▏                                        | 1/20 [04:42<1:29:31, 282.73s/it]
# Epoch [1/20], Training Loss: 0.6257, Validation Loss: 0.6349
#   5%|██▏                                        | 1/20 [05:37<1:47:00, 337.93s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[138], line 10
#       8 # Training data generator
#       9 train_data_gen = data_generator(train_batch_files, batch_size)
# ---> 10 for batch_images, batch_labels in train_data_gen:
#      11     batch_images = batch_images.to(device)
#      12     batch_labels = batch_labels.to(device)
#
# Cell In[23], line 7, in data_generator(batch_files, batch_size)
#       4 labels_array = training_classifications_df.iloc[:, 1:].values
#       6 for batch in batch_files:
# ----> 7     images = np.array(load(batch))
#       9     # images is a numpy array of shape (height, width, channels)
#      10     num_images = len(images)
#
# File ~/anaconda3/envs/astrods/lib/python3.11/site-packages/joblib/numpy_pickle.py:658, in load(filename, mmap_mode)
#     652             if isinstance(fobj, str):
#     653                 # if the returned file object is a string, this means we
#     654                 # try to load a pickle file generated with an version of
#     655                 # Joblib so we load it with joblib compatibility function.
#     656                 return load_compatibility(fobj)
# --> 658             obj = _unpickle(fobj, filename, mmap_mode)
#     659 return obj
#
# File ~/anaconda3/envs/astrods/lib/python3.11/site-packages/joblib/numpy_pickle.py:577, in _unpickle(fobj, filename, mmap_mode)
#     575 obj = None
#     576 try:
# --> 577     obj = unpickler.load()
#     578     if unpickler.compat_mode:
#     579         warnings.warn("The file '%s' has been generated with a "
#     580                       "joblib version less than 0.10. "
#     581                       "Please regenerate this pickle file."
#     582                       % filename,
#     583                       DeprecationWarning, stacklevel=3)
#
# File ~/anaconda3/envs/astrods/lib/python3.11/pickle.py:1213, in _Unpickler.load(self)
#    1211             raise EOFError
#    1212         assert isinstance(key, bytes_types)
# -> 1213         dispatch[key[0]](self)
#    1214 except _Stop as stopinst:
#    1215     return stopinst.value
#
# File ~/anaconda3/envs/astrods/lib/python3.11/site-packages/joblib/numpy_pickle.py:415, in NumpyUnpickler.load_build(self)
#     413 if isinstance(array_wrapper, NDArrayWrapper):
#     414     self.compat_mode = True
# --> 415 self.stack.append(array_wrapper.read(self))
#
# File ~/anaconda3/envs/astrods/lib/python3.11/site-packages/joblib/numpy_pickle.py:252, in NumpyArrayWrapper.read(self, unpickler)
#     250     array = self.read_mmap(unpickler)
#     251 else:
# --> 252     array = self.read_array(unpickler)
#     254 # Manage array subclass case
#     255 if (hasattr(array, '__array_prepare__') and
#     256     self.subclass not in (unpickler.np.ndarray,
#     257                           unpickler.np.memmap)):
#     258     # We need to reconstruct another subclass
#
# File ~/anaconda3/envs/astrods/lib/python3.11/site-packages/joblib/numpy_pickle.py:177, in NumpyArrayWrapper.read_array(self, unpickler)
#     175 read_count = min(max_read_count, count - i)
#     176 read_size = int(read_count * self.dtype.itemsize)
# --> 177 data = _read_bytes(unpickler.file_handle,
#     178                    read_size, "array data")
#     179 array[i:i + read_count] = \
#     180     unpickler.np.frombuffer(data, dtype=self.dtype,
#     181                             count=read_count)
#     182 del data
#
# File ~/anaconda3/envs/astrods/lib/python3.11/site-packages/joblib/numpy_pickle_utils.py:243, in _read_bytes(fp, size, error_template)
#     238 while True:
#     239     # io files (default in python3) return None or raise on
#     240     # would-block, python2 file will truncate, probably nothing can be
#     241     # done about that.  note that regular files can't be non-blocking
#     242     try:
# --> 243         r = fp.read(size - len(data))
#     244         data += r
#     245         if len(r) == 0 or len(data) == size:
#
# KeyboardInterrupt:
